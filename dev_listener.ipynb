# %%
from shopee_crawler import ShopeeCrawler
from product_info_listener import ProductInfoListener

# %%
crawler = ShopeeCrawler("樹沒派",1)
crawler

# %%
df = crawler.collect_info_into_df()
# Out:
# Open Url: https://shopee.tw/search?keyword=樹沒派
# Open Url: https://shopee.tw/
# Open Url: https://shopee.tw/search?keyword=樹沒派&page=0
# Till Button
# Scraping...
# collected.
# Closing Browser..
# Browser is closed
# 1/61
# Open Url: https://shopee.tw/%E3%80%90%E5%82%91%E6%A3%AE%E5%89%B5%E5%B7%A5%E3%80%91%E6%A8%B9%E8%8E%93%E6%B4%BE%E5%B0%88%E7%94%A8-7%E5%90%8B%E8%A7%B8%E6%8E%A7%E8%9E%A2%E5%B9%95-LCD%EF%BC%8C%E5%85%8D%E9%A9%85%E5%8B%95%EF%BC%8C%E9%80%81%E5%A4%96%E6%AE%BC%E6%94%AF%E6%9E%B6%EF%BC%81%E7%9B%B8%E5%AE%B9%E6%A8%B9%E8%8E%93%E6%B4%BE3B-4B-Zero%E5%8F%8AWindwos-i.20917936.4525416842?sp_atk=69d4415a-8bd2-4f71-a548-823fd3356d6a&xptdk=69d4415a-8bd2-4f71-a548-823fd3356d6a
# [css selector] ._44qnta for product_name is not exists.
# [css selector] ._046PXf for number_of_stars is not exists.
# [css selector] div.IZIVH\+:nth-child(2) for number_of_comments is not exists.
# [css selector] .jgUbWJ for quantity_sold is not exists.
# ...

# %%
df["chat_response_speed"]
# Out:
# 0     幾小時內
# 1     幾小時內
# 2     幾小時內
# 3     幾小時內
# 4     幾小時內
# 5     幾小時內
# 6     幾小時內
# 7     幾小時內
# 8     幾分鐘內
# 9     幾小時內
# 10    幾小時內
# 11    幾分鐘內
# 12    幾小時內
# 13    幾小時內
# 14    幾小時內
# 15    幾小時內
# 16    幾小時內
# 17    幾小時內
# 18    幾小時內
# 19    幾小時內
# 20    幾分鐘內
# 21    幾小時內
# 22    幾小時內
# 23    幾小時內
# 24    幾小時內
# 25    幾小時內
# 26    幾小時內
# 27    幾小時內
# 28    幾小時內
# 29    幾小時內
# 30    幾小時內
# 31    幾小時內
# 32    幾小時內
# 33    幾小時內
# 34    幾小時內
# 35    幾小時內
# 36    幾小時內
# 37    幾小時內
# 38    幾小時內
# 39    幾小時內
# 40    幾小時內
# 41    幾小時內
# 42    幾小時內
# 43    幾小時內
# 44    幾小時內
# 45    幾小時內
# 46    幾小時內
# 47    幾小時內
# 48    幾小時內
# 49    幾小時內
# 50    幾小時內
# 51    幾小時內
# 52    幾小時內
# 53    幾小時內
# 54    幾小時內
# 55    幾小時內
# 56    幾小時內
# 57    幾小時內
# 58    幾小時內
# Name: chat_response_speed, dtype: object

# %%
import pandas as pd
pd.DataFrame(
                [info.info_dict for info in scraper.listener_browser.info_scraped]
            )

# %%
ProductInfoListener().run()
